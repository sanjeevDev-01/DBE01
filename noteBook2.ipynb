# %% [markdown]
# ## Databricks Utilities
# - File System utlities
# - Secrets utilitis
# - widget utilities

# %%
# %fs ls /

# %%
dbutils.fs.ls('/')

# %%
display(dbutils.fs.ls('/'))

# %%
# %fs ls dbfs:/databricks-datasets/

# %%
items=dbutils.fs.ls('/databricks-datasets/')
for item in items:   
    print(item.name.endswith("/"))

# %%
#Count the folders and files
folder_count=len([item for item in items if item.name.endswith("/")])
file_count=len([item for item in items if not item.name.endswith("/")])

# Display the counts

print(f"Total folders :{folder_count}")
print(f"Total Files : {file_count}")
